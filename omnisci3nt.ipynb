# %%
# !git clone https://github.com/spyboy-productions/omnisci3nt.git
# Out:
# Cloning into 'omnisci3nt'...
# remote: Enumerating objects: 207, done.
# remote: Counting objects: 100% (118/118), done.
# remote: Compressing objects: 100% (88/88), done.
# remote: Total 207 (delta 72), reused 40 (delta 30), pack-reused 89
# Receiving objects: 100% (207/207), 8.31 MiB | 18.38 MiB/s, done.
# Resolving deltas: 100% (101/101), done.

# %%
cd omnisci3nt
# Out:
# /content/omnisci3nt

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.3/103.3 kB 3.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.7/307.7 kB 10.0 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.7/288.7 kB 12.3 MB/s eta 0:00:00
# ...
#   Created wheel for builtwith: filename=builtwith-1.3.4-py3-none-any.whl size=36079 sha256=2ee12afcbf249b9ac933c352b387a60fd88451d59b690bfe4ae4683c202bdf14
#   Stored in directory: /root/.cache/pip/wheels/6e/bf/03/4e45fb3049b99c21360499dfdad979d11b73e972fb2d3ad56c
# Successfully built builtwith
# ...

# %%
# !python omnisci3nt.py
# Out:
#
#                       .__              .__________         __
#   ____   _____   ____ |__| ______ ____ |__\_____  \  _____/  |_
#  /  _ \ /     \ /    \|  |/  ___// ___\|  | _(__  < /    \   __\
# (  <_> )  Y Y  \   |  \  |\___ \\  \___|  |/       \   |  \  |
#  \____/|__|_|  /___|  /__/____  >\___  >__/______  /___|  /__|
#              \/     \/        \/     \/          \/     \/
#     Unveiling the Hidden Layers of the Web.
#
#
#
# ╰➤ Version      : 1.0.2
# ╰➤ Creator      : Spyboy
# ╰➤ Twitter      : https://spyboy.in/twitter
# ╰➤ Discord      : https://spyboy.in/Discord
# ╰➤ Website      : https://spyboy.in/
# ╰➤ Blog         : https://spyboy.blog/
# ╰➤ Github       : https://github.com/spyboy-productions/omnisci3nt
#
# Enter Domain or URL:spyboy.blog
#
#     ￣￣￣￣￣￣￣￣￣￣￣￣
#        Recon Started
#     ＿＿＿＿＿＿＿＿＿＿＿＿
#           \(•◡•)/
#            \   /
#             ———
#            |   |
#            |   |
#
#
# [~] IP lookup :
#
# ╰➤ IP: 192.0.78.24
# ...
